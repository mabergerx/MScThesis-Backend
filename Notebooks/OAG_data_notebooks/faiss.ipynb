# %% [markdown]
# # Testing out Faiss

# %%
import os
import time
import math
import random
import numpy as np
import json
from sklearn.preprocessing import normalize
import faiss

# res = faiss.StandardGpuResources()  # use a single GPU

def dist2sim(d):
    return 1 - d / 2

# %%
def get_index(index_type, dim):
    if index_type == 'hnsw':
        m = 48
        index = faiss.IndexHNSWFlat(dim, m)
        index.hnsw.efConstruction = 128
        # gpu_index = faiss.index_cpu_to_gpu(res, 0, index)
        return index
    elif index_type == 'l2':
        index = faiss.IndexFlatL2(dim)
        # gpu_index = faiss.index_cpu_to_gpu(res, 0, index)
        return index
    raise

# %%
def populate(index, fvecs, batch_size=10000):
    nloop = math.ceil(fvecs.shape[0] / batch_size)
    for n in range(nloop):
        s = time.time()
        index.add(normalize(fvecs[n * batch_size : min((n + 1) * batch_size, fvecs.shape[0])]))
        print(n * batch_size, time.time() - s)

    return index

# %%
def populate_and_index_map(index, vectors, ids=ids_for_faiss_idmap):
    mapper = faiss.IndexIDMap(index)
    mapper.add_with_ids(normalize(vectors), ids_for_faiss_idmap)
    return mapper

# %%
dim = 768
index_type = 'hnsw'
index = get_index(index_type, dim)

# %%
import numpy as np
d = 768                          # dimension
nb = 10000                       # database size
# nq = 10                         # nb of queries
np.random.seed(42)             # make reproducible
xb = (np.random.uniform(-1, 1, (nb, d))/10).astype('float32')
# xb[:, 0] += np.arange(nb) / 1000.
# xq = (np.random.uniform(-1, 1, (nq, d))/10).astype('float32')
# xq[:, 0] += np.arange(nq) / 1000.

# %%
nq = 10                         # nb of queries
xq = (np.random.uniform(-1, 1, (nq, d))/10).astype('float32')

# %%
index = populate(index, xb)
# Out:
# 0 0.07434678077697754
# 1000 0.14951086044311523
# 2000 0.19786739349365234
# 3000 0.28281164169311523
# 4000 0.33390212059020996
# 5000 0.39216113090515137
# 6000 0.4473230838775635
# 7000 0.502324104309082
# 8000 0.5784924030303955
# 9000 0.5920150279998779

# %%
index.is_trained
# Out:
# True

# %%
index.ntotal
# Out:
# 10000

# %%
k = 4
s = time.time()
dists, idxs = index.search(normalize(xq), k)
print((time.time() - s) / len(xq))
print(idxs[0], dist2sim(dists[0]))
# Out:
# 0.0002969503402709961
# [2922  208 9244 8449] [0.12403476 0.11176467 0.10933161 0.09883845]

# %%
# faiss.write_index(index, "mock_vectors.index")

# %%
# laoaded_index = faiss.read_index("mock_vectors.index")

# %%
# laoaded_index.hnsw.efSearch =  256

# %%
# k = 10
# s = time.time()
# dists, idxs = laoaded_index.search(normalize(xq), k)
# print((time.time() - s) / len(xq))
# print(idxs[0], dist2sim(dists[0]))

# %% [markdown]
# # Real vectors

# %%
import pandas as pd

# %%
data = pd.read_pickle("FINAL_data_and_embeddings/data_with_title_embeddings.pkl")

# %%
data.sample()
# Out:
#                id                                              title  \
# 43658  2254177447  Semantic Image Segmentation with Task-Specific...
#
#                                                  authors  \
# 43658  [{'name': 'Liang-Chieh Chen', 'id': '212789804...
#
#                                                    venue  year  n_citation  \
# 43658  {'raw': 'computer vision and pattern recogniti...  2016          56
#
#       page_start page_end    doc_type publisher volume issue  \
# 43658       4545     4554  Conference      IEEE
#
#                                                      fos  \
# 43658  [{'name': 'Computer vision', 'w': 0.440761358}...
#
#                          doi  \
# 43658  10.1109/CVPR.2016.492
#
#                                               references  \
# 43658  [825165083, 845365781, 1495267108, 1529410181,...
#
#                                         indexed_abstract  \
# 43658  {'IndexLength': 134, 'InvertedIndex': {'Deep':...
#
#                                                 abstract  \
# 43658  Deep convolutional neural networks (CNNs) are ...
#
#                               cleaned_abstract_sentences  \
# 43658  [deep convolutional neural networks cnns are t...
#
#                                            cleaned_title  \
# 43658  semantic image segmentation with task specific...
#
#                                          title_embedding
# 43658  [0.7282408, -0.56314397, -0.5906662, 0.9875755...

# %%
data_with_retrofitted = pd.read_pickle("FINAL_data_and_embeddings/final_embeddings/data_with_retrofitted_embeddings.pkl")

# %%
data_with_retrofitted.sample()
# Out:
#                id                                         references  \
# 96964  1988737268  [15605318, 1489448163, 1559371027, 1564628430,...
#
#                                                   merged  \
# 96964  [0.4173065113524596, -0.23755234324683747, -0....
#
#                                                 separate  \
# 96964  [0.38529178500175476, -0.45145511627197266, -0...
#
#                                       retrofitted_merged  \
# 96964  [0.03568840776127606, -0.026547973741589244, -...
#
#                                     retrofitted_separate
# 96964  [0.031883103531993646, -0.03341143669524094, -...

# %%
data_with_retrofitted.iloc[67890]
# Out:
# id                                                             1961300657
# references                                                   [2097192888]
# merged                  [-0.325588196516037, 0.23439041152596474, -0.0...
# separate                [-0.33311566710472107, 0.3387480080127716, 0.0...
# retrofitted_merged      [-0.028069935572412445, 0.020207500826895, -0....
# retrofitted_separate    [-0.026874356915329287, 0.027328750253076968, ...
# Name: 67890, dtype: object

# %%
data["retro_merged"] = data_with_retrofitted["retrofitted_merged"]
data["retro_separate"] = data_with_retrofitted["retrofitted_separate"]
data["merged"] = data_with_retrofitted["merged"]
data["separate"] = data_with_retrofitted["separate"]

# %%
data.drop([63376], inplace=True) #strange abstract with no readable text
data.reset_index(drop=True, inplace=True)

# %%
def correct_retrofitted_separate(row):
    separate = row.separate
    retro = row.retro_separate
    
    if np.isnan(retro[0]):
        return separate
    else:
        return retro

# %%
data["retro_separate_corrected"] = data.apply(lambda x: correct_retrofitted_separate(x), axis=1)

# %%
# data.to_pickle("data_with_all_corrected_sbert_embeddings.pkl")

# %%
# {63376, 63411, 69199, 69201, 69219, 69225, 79760}
# data.iloc[69218]

# %%
# data.to_pickle("data_with_all_sbert_embeddings.pkl")

# %%
# m_e = np.array(data["merged"][0])

# %%
merged_embeddings = np.float32(np.array([np.array(m) for m in data.merged.to_numpy()]))

# %%
separate_embeddings = np.float32(np.array([np.array(m) for m in data.separate.to_numpy()]))

# %%
separate_retro_embeddings = np.float32(np.array([np.array(m) for m in data.retro_separate_corrected.to_numpy()]))

# %%
merged_retro_embeddings = np.float32(np.array([np.array(m) for m in data.retro_merged.to_numpy()]))

# %%
separate_embeddings.shape
# Out:
# (127716, 768)

# %%
merged_embeddings.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-175502d5a9f4> in <module>()
# ----> 1 merged_embeddings.shape
#
# NameError: name 'merged_embeddings' is not defined

# %%
separate_retro_embeddings.shape
# Out:
# (127716, 768)

# %%
merged_retro_embeddings.shape
# Out:
# (127716, 768)

# %%
dim = 768
index_type = 'hnsw'
merged_embeddings_index = get_index(index_type, dim)

separate_embeddings_index = get_index(index_type, dim)
retro_separate_embeddings_index = get_index(index_type, dim)
retro_merged_embeddings_index = get_index(index_type, dim)

# %%
merged_embeddings_index = populate(merged_embeddings_index, merged_embeddings)
faiss.write_index(merged_embeddings_index, "merged_embeddings_faiss.index")

separate_embeddings_index = populate(separate_embeddings_index, separate_embeddings)
faiss.write_index(separate_embeddings_index, "separate_embeddings_faiss.index")

retro_separate_embeddings_index = populate(retro_separate_embeddings_index, separate_retro_embeddings)
faiss.write_index(retro_separate_embeddings_index, "retro_separate_embeddings_faiss.index")

retro_merged_embeddings_index = populate(retro_merged_embeddings_index, merged_retro_embeddings)
faiss.write_index(retro_merged_embeddings_index, "retro_merged_embeddings_faiss.index")
# Out:
# 0 0.031844139099121094
# 1000 0.059911251068115234
# 2000 0.07129979133605957
# 3000 0.08702206611633301
# 4000 0.09132814407348633
# 5000 0.10360360145568848
# 6000 0.1086282730102539
# 7000 0.11718153953552246
# 8000 0.13128876686096191
# 9000 0.12652325630187988
# 10000 0.1412053108215332
# 11000 0.16633915901184082
# 12000 0.14229154586791992
# 13000 0.15894556045532227
# 14000 0.1808767318725586
# 15000 0.17592525482177734
# 16000 0.19408035278320312
# 17000 0.1464383602142334
# 18000 0.16267681121826172
# 19000 0.17173290252685547
# 20000 0.1857616901397705
# 21000 0.1758744716644287
# 22000 0.19088363647460938
# 23000 0.20973491668701172
# 24000 0.18694233894348145
# 25000 0.19225358963012695
# 26000 0.21924233436584473
# 27000 0.20987367630004883
# 28000 0.21449804306030273
# 29000 0.21845579147338867
# 30000 0.20595479011535645
# 31000 0.2428264617919922
# 32000 0.32498955726623535
# 33000 0.2404172420501709
# 34000 0.23930644989013672
# 35000 0.2664647102355957
# 36000 0.2369229793548584
# 37000 0.26708507537841797
# 38000 0.22872424125671387
# 39000 0.2317969799041748
# 40000 0.25624871253967285
# 41000 0.24382448196411133
# 42000 0.24204373359680176
# 43000 0.26018834114074707
# 44000 0.25288867950439453
# 45000 0.29317474365234375
# 46000 0.2828836441040039
# 47000 0.2966029644012451
# 48000 0.2856144905090332
# 49000 0.28422093391418457
# 50000 0.24042844772338867
# 51000 0.2808065414428711
# 52000 0.2889542579650879
# 53000 0.27683448791503906
# 54000 0.3172187805175781
# 55000 0.27425193786621094
# 56000 0.27512526512145996
# 57000 0.28417229652404785
# 58000 0.29753899574279785
# 59000 0.307797908782959
# 60000 0.3321998119354248
# 61000 0.31665682792663574
# 62000 0.3102736473083496
# 63000 0.31989502906799316
# 64000 0.4823322296142578
# 65000 0.31900668144226074
# 66000 0.3392341136932373
# 67000 0.31087779998779297
# 68000 0.30480074882507324
# 69000 0.2961764335632324
# 70000 0.31716227531433105
# 71000 0.32047224044799805
# 72000 0.35048794746398926
# 73000 0.3227968215942383
# 74000 0.32102513313293457
# 75000 0.3224296569824219
# 76000 0.35185718536376953
# 77000 0.3321359157562256
# 78000 0.3544955253601074
# 79000 0.3425467014312744
# 80000 0.3508930206298828
# 81000 0.35461997985839844
# 82000 0.3273167610168457
# 83000 0.32071900367736816
# 84000 0.3406524658203125
# 85000 0.3230774402618408
# 86000 0.3614928722381592
# 87000 0.3038947582244873
# 88000 0.3603696823120117
# 89000 0.33923935890197754
# 90000 0.3521280288696289
# 91000 0.31911754608154297
# 92000 0.36100339889526367
# 93000 0.3573873043060303
# 94000 0.35446691513061523
# 95000 0.3375256061553955
# 96000 0.38362765312194824
# 97000 0.34813547134399414
# 98000 0.37847018241882324
# 99000 0.38590049743652344
# 100000 0.35429906845092773
# 101000 0.3890063762664795
# 102000 0.40710878372192383
# 103000 0.37839341163635254
# 104000 0.3652372360229492
# 105000 0.36438751220703125
# 106000 0.40731263160705566
# 107000 0.39223551750183105
# 108000 0.37747716903686523
# 109000 0.36652469635009766
# 110000 0.4049832820892334
# 111000 0.3742079734802246
# 112000 0.38390612602233887
# 113000 0.3398101329803467
# 114000 0.3899521827697754
# 115000 0.3743596076965332
# 116000 0.38649678230285645
# 117000 0.38182497024536133
# 118000 0.39170050621032715
# 119000 0.3915829658508301
# 120000 0.3658261299133301
# 121000 0.38501572608947754
# 122000 0.36728763580322266
# 123000 0.3811640739440918
# 124000 0.37353968620300293
# 125000 0.4019491672515869
# 126000 0.42983508110046387
# 127000 0.2728536128997803
# 0 0.03155994415283203
# 1000 0.06277227401733398
# 2000 0.07351016998291016
# 3000 0.0895230770111084
# 4000 0.09338808059692383
# 5000 0.1111745834350586
# 6000 0.11435437202453613
# 7000 0.11954092979431152
# 8000 0.13205480575561523
# 9000 0.13761210441589355
# 10000 0.1418602466583252
# 11000 0.17940616607666016
# 12000 0.14391684532165527
# 13000 0.16347980499267578
# 14000 0.17612123489379883
# 15000 0.17580389976501465
# 16000 0.18769574165344238
# 17000 0.1629161834716797
# 18000 0.17084693908691406
# 19000 0.18566560745239258
# 20000 0.1852118968963623
# 21000 0.18805384635925293
# 22000 0.2078077793121338
# 23000 0.21518993377685547
# 24000 0.19566798210144043
# 25000 0.2088603973388672
# 26000 0.22645068168640137
# 27000 0.22402191162109375
# 28000 0.2142317295074463
# 29000 0.22472023963928223
# 30000 0.20889544486999512
# 31000 0.24118614196777344
# 32000 0.3033173084259033
# 33000 0.24082016944885254
# 34000 0.22339844703674316
# 35000 0.25760817527770996
# 36000 0.24960708618164062
# 37000 0.27909159660339355
# 38000 0.23952102661132812
# 39000 0.2567887306213379
# 40000 0.26630115509033203
# 41000 0.25358128547668457
# 42000 0.2651803493499756
# 43000 0.26949238777160645
# 44000 0.2500901222229004
# 45000 0.28705501556396484
# 46000 0.27762532234191895
# 47000 0.29833364486694336
# 48000 0.27765727043151855
# 49000 0.2811086177825928
# 50000 0.24852848052978516
# 51000 0.2812690734863281
# 52000 0.28513264656066895
# 53000 0.28212594985961914
# 54000 0.3160984516143799
# 55000 0.2961692810058594
# 56000 0.27905702590942383
# 57000 0.28980040550231934
# 58000 0.2831132411956787
# 59000 0.2849915027618408
# 60000 0.2972142696380615
# 61000 0.2806582450866699
# 62000 0.2989795207977295
# 63000 0.30364274978637695
# 64000 0.49006032943725586
# 65000 0.3096628189086914
# 66000 0.29415225982666016
# 67000 0.30031776428222656
# 68000 0.31111884117126465
# 69000 0.297649621963501
# 70000 0.3090174198150635
# 71000 0.32238078117370605
# 72000 0.3443729877471924
# 73000 0.32054901123046875
# 74000 0.31735968589782715
# 75000 0.3211636543273926
# 76000 0.34696388244628906
# 77000 0.32647204399108887
# 78000 0.3224601745605469
# 79000 0.3053460121154785
# 80000 0.3217966556549072
# 81000 0.3444936275482178
# 82000 0.3174121379852295
# 83000 0.31731629371643066
# 84000 0.33580851554870605
# 85000 0.32414841651916504
# 86000 0.368863582611084
# 87000 0.35849523544311523
# 88000 0.35840940475463867
# 89000 0.3385641574859619
# 90000 0.3494899272918701
# 91000 0.32762670516967773
# 92000 0.3656435012817383
# 93000 0.36940455436706543
# 94000 0.37677478790283203
# 95000 0.3419191837310791
# 96000 0.3823709487915039
# 97000 0.37943005561828613
# 98000 0.4010481834411621
# 99000 0.37763333320617676
# 100000 0.3486640453338623
# 101000 0.39410972595214844
# 102000 0.4123871326446533
# 103000 0.39179062843322754
# 104000 0.36878538131713867
# 105000 0.36071276664733887
# 106000 0.36966753005981445
# 107000 0.39156436920166016
# 108000 0.37491297721862793
# 109000 0.3587822914123535
# 110000 0.4091825485229492
# 111000 0.3803584575653076
# 112000 0.39860987663269043
# 113000 0.37718653678894043
# 114000 0.42380785942077637
# 115000 0.39601850509643555
# 116000 0.3855133056640625
# 117000 0.3651401996612549
# 118000 0.39191603660583496
# 119000 0.41901421546936035
# 120000 0.4387083053588867
# 121000 0.43314146995544434
# 122000 0.4141411781311035
# 123000 0.41033387184143066
# 124000 0.3844308853149414
# 125000 0.421952486038208
# 126000 0.42232823371887207
# 127000 0.2831096649169922
# 0 0.028423547744750977
# 1000 0.05488991737365723
# 2000 0.06165266036987305
# 3000 0.07437658309936523
# 4000 0.07739996910095215
# 5000 0.08706808090209961
# 6000 0.09268665313720703
# 7000 0.1025540828704834
# 8000 0.10497117042541504
# 9000 0.10541462898254395
# 10000 0.10809993743896484
# 11000 0.13531899452209473
# 12000 0.1064600944519043
# 13000 0.12211298942565918
# 14000 0.13199353218078613
# 15000 0.13198566436767578
# 16000 0.14660310745239258
# 17000 0.12304186820983887
# 18000 0.12575054168701172
# 19000 0.1325998306274414
# 20000 0.13425159454345703
# 21000 0.13226914405822754
# 22000 0.14880657196044922
# 23000 0.16762733459472656
# 24000 0.14681386947631836
# 25000 0.15224099159240723
# 26000 0.16246652603149414
# 27000 0.1727294921875
# 28000 0.15714550018310547
# 29000 0.17569303512573242
# 30000 0.1483619213104248
# 31000 0.1906754970550537
# 32000 0.26076245307922363
# 33000 0.17314839363098145
# 34000 0.16104626655578613
# 35000 0.17662787437438965
# 36000 0.17037487030029297
# 37000 0.18558454513549805
# 38000 0.17003607749938965
# 39000 0.17294716835021973
# 40000 0.18987154960632324
# 41000 0.1732933521270752
# 42000 0.17870235443115234
# 43000 0.19518566131591797
# 44000 0.1935122013092041
# 45000 0.21213650703430176
# 46000 0.19760394096374512
# 47000 0.2102677822113037
# 48000 0.21043634414672852
# 49000 0.21591567993164062
# 50000 0.18215680122375488
# 51000 0.21583890914916992
# 52000 0.216339111328125
# 53000 0.20601916313171387
# 54000 0.23049497604370117
# 55000 0.18999171257019043
# 56000 0.2113957405090332
# 57000 0.22254085540771484
# 58000 0.20706677436828613
# 59000 0.2176368236541748
# 60000 0.23087167739868164
# 61000 0.2145371437072754
# 62000 0.23070049285888672
# 63000 0.2294313907623291
# 64000 0.39678287506103516
# 65000 0.23886585235595703
# 66000 0.2317516803741455
# 67000 0.21721768379211426
# 68000 0.23241448402404785
# 69000 0.23036575317382812
# 70000 0.2393050193786621
# 71000 0.23361539840698242
# 72000 0.2652122974395752
# 73000 0.24927306175231934
# 74000 0.24224281311035156
# 75000 0.24634361267089844
# 76000 0.28011345863342285
# 77000 0.2739541530609131
# 78000 0.2608211040496826
# 79000 0.22701311111450195
# 80000 0.2556145191192627
# 81000 0.25931835174560547
# 82000 0.24768900871276855
# 83000 0.23849153518676758
# 84000 0.2579686641693115
# 85000 0.24144864082336426
# 86000 0.2799234390258789
# 87000 0.24551105499267578
# 88000 0.26792287826538086
# 89000 0.2653491497039795
# 90000 0.27115440368652344
# 91000 0.24843478202819824
# 92000 0.27094340324401855
# 93000 0.26431941986083984
# 94000 0.2531163692474365
# 95000 0.23514533042907715
# 96000 0.27440786361694336
# 97000 0.259645938873291
# 98000 0.27513623237609863
# 99000 0.2902977466583252
# 100000 0.24010324478149414
# 101000 0.2769184112548828
# 102000 0.2886953353881836
# 103000 0.26180481910705566
# 104000 0.2610783576965332
# 105000 0.2534291744232178
# 106000 0.2490983009338379
# 107000 0.27767014503479004
# 108000 0.26326823234558105
# 109000 0.24972891807556152
# 110000 0.2741055488586426
# 111000 0.25449633598327637
# 112000 0.278076171875
# 113000 0.2313075065612793
# 114000 0.25290513038635254
# 115000 0.27075862884521484
# 116000 0.2941012382507324
# 117000 0.30390071868896484
# 118000 0.2846996784210205
# 119000 0.28159570693969727
# 120000 0.258807897567749
# 121000 0.2827005386352539
# 122000 0.26311731338500977
# 123000 0.2876465320587158
# 124000 0.2889864444732666
# 125000 0.31307363510131836
# 126000 0.3099210262298584
# 127000 0.21037626266479492
# 0 0.027380704879760742
# 1000 0.04960966110229492
# 2000 0.05760025978088379
# 3000 0.0655360221862793
# 4000 0.06933903694152832
# 5000 0.07629728317260742
# 6000 0.0787208080291748
# 7000 0.08742451667785645
# 8000 0.0922551155090332
# 9000 0.0942835807800293
# 10000 0.09925103187561035
# 11000 0.11760544776916504
# 12000 0.0965886116027832
# 13000 0.10850787162780762
# 14000 0.11113405227661133
# 15000 0.1159665584564209
# 16000 0.1598680019378662
# 17000 0.10862541198730469
# 18000 0.11233210563659668
# 19000 0.12166929244995117
# 20000 0.1236410140991211
# 21000 0.12176752090454102
# 22000 0.13570594787597656
# 23000 0.14522624015808105
# 24000 0.13152408599853516
# 25000 0.13040447235107422
# 26000 0.14783954620361328
# 27000 0.145430326461792
# 28000 0.14141249656677246
# 29000 0.14938831329345703
# 30000 0.13543343544006348
# 31000 0.16465020179748535
# 32000 0.23806047439575195
# 33000 0.15652036666870117
# 34000 0.1427755355834961
# 35000 0.16679954528808594
# 36000 0.1682298183441162
# 37000 0.16912078857421875
# 38000 0.15461325645446777
# 39000 0.1532139778137207
# 40000 0.17915916442871094
# 41000 0.165757417678833
# 42000 0.1683213710784912
# 43000 0.1742246150970459
# 44000 0.1703183650970459
# 45000 0.18817615509033203
# 46000 0.17421388626098633
# 47000 0.18066644668579102
# 48000 0.19547820091247559
# 49000 0.20004987716674805
# 50000 0.22379612922668457
# 51000 0.18595409393310547
# 52000 0.1944277286529541
# 53000 0.18559670448303223
# 54000 0.21329069137573242
# 55000 0.17739248275756836
# 56000 0.18573999404907227
# 57000 0.21108365058898926
# 58000 0.20613408088684082
# 59000 0.21414995193481445
# 60000 0.21978163719177246
# 61000 0.23144006729125977
# 62000 0.22992300987243652
# 63000 0.22159457206726074
# 64000 0.3817300796508789
# 65000 0.2139885425567627
# 66000 0.19846272468566895
# 67000 0.19838809967041016
# 68000 0.19477272033691406
# 69000 0.1936485767364502
# 70000 0.21724319458007812
# 71000 0.21574807167053223
# 72000 0.2318727970123291
# 73000 0.20972919464111328
# 74000 0.21915864944458008
# 75000 0.22121810913085938
# 76000 0.2383108139038086
# 77000 0.21773695945739746
# 78000 0.21668076515197754
# 79000 0.20604777336120605
# 80000 0.2263195514678955
# 81000 0.24033141136169434
# 82000 0.21564006805419922
# 83000 0.21806669235229492
# 84000 0.2237856388092041
# 85000 0.21360230445861816
# 86000 0.23058581352233887
# 87000 0.1993393898010254
# 88000 0.23426246643066406
# 89000 0.23538947105407715
# 90000 0.22866106033325195
# 91000 0.22241830825805664
# 92000 0.2414259910583496
# 93000 0.2377784252166748
# 94000 0.2419421672821045
# 95000 0.22597336769104004
# 96000 0.2538275718688965
# 97000 0.2447218894958496
# 98000 0.26157379150390625
# 99000 0.25293779373168945
# 100000 0.2363440990447998
# 101000 0.2802596092224121
# 102000 0.3214859962463379
# 103000 0.28537702560424805
# 104000 0.2456188201904297
# 105000 0.2430572509765625
# 106000 0.24994421005249023
# 107000 0.26656508445739746
# 108000 0.2628955841064453
# 109000 0.2527480125427246
# 110000 0.27568507194519043
# 111000 0.2646219730377197
# 112000 0.27233099937438965
# 113000 0.2509915828704834
# 114000 0.2511467933654785
# 115000 0.2598237991333008
# 116000 0.25921130180358887
# 117000 0.2682919502258301
# 118000 0.2555985450744629
# 119000 0.252671480178833
# 120000 0.23945403099060059
# 121000 0.26930737495422363
# 122000 0.24168825149536133
# 123000 0.2548491954803467
# 124000 0.2580726146697998
# 125000 0.2653017044067383
# 126000 0.28365445137023926
# 127000 0.19356584548950195

# %%
set([t[0] for t in np.argwhere(np.isnan(separate_retro_embeddings))])
# Out:
# {63376, 63411, 69199, 69201, 69219, 69225, 79760}

# %%
set([t[0] for t in np.argwhere(np.isnan(separate_embeddings))])
# Out:
# {63376}

# %%
random.seed(2020)
q_idx = [random.randint(0, merged_embeddings.shape[0]) for _ in range(100)]

k = 10
s = time.time()
dists, idxs = merged_embeddings_index.search(normalize(merged_embeddings[q_idx]), k)
print((time.time() - s) / len(q_idx))
print(idxs[0], dist2sim(dists[0]))
# Out:
# 7.747650146484375e-05
# [111806  46256 110282    474  99043  15540  91718  86581  25530  71084] [0.7220207  0.7070291  0.6979676  0.6947185  0.69459105 0.6912974
#  0.6819054  0.68079495 0.6784862  0.67215836]

# %%
# faiss.write_index(merged_embeddings_index, "merged_embeddings_faiss.index")

# %%
retro_merged_embeddings_index.ntotal
# Out:
# 127716

# %%
retro_separate_embeddings_index.ntotal
# Out:
# 127716

# %%
merged_embeddings_index.ntotal
# Out:
# 127716

# %%
separate_embeddings_index.ntotal
# Out:
# 127716

# %%
ids_for_faiss_idmap = np.array([int(m) for m in data.id])

# %%
np.save("ids_for_faiss_idmap.npy", ids_for_faiss_idmap)

# %%
test_index = get_index(index_type, dim)

# %%
test_index
# Out:
# <faiss.swigfaiss.IndexHNSWFlat; proxy of <Swig Object of type 'faiss::IndexHNSWFlat *' at 0x7fc1d2c557b0> >

# %%
test_index2 = faiss.IndexIDMap(test_index)

# %%
test_index2.add_with_ids(normalize(merged_embeddings[:100000]), ids_for_faiss_idmap[:100000])

# %%
random.seed(2020)
q_idx = [random.randint(0, merged_embeddings.shape[0]) for _ in range(100)]

k = 100000
s = time.time()
dists, idxs = test_index2.search(normalize(merged_embeddings[q_idx]), k)
print((time.time() - s) / len(q_idx))
print(idxs[0][:50], dist2sim(dists[0][:50]))
# Out:
# 0.00024907350540161134
# [2127650263 2085583171 2160684493 1595483645 2142544755 2194321275
#  2340427832 2170805580 2770298516 2130105540 2751118800 2164479831
#  1993309788 1892722218 2467980042 2123967136 2121557314 2214145768
#   208252816 2029269644 2269778407 2130318956 2074668887 1504448809
#  2593658277 2015103117 2006273250 2767050701 2564726951 2588610957
#  1983801113   53987483 2006859604 1987326241 2118459920 1989549063
#  1987409251 1965417459 2040990302  105964407 2146571341 2113592754
#  2201912979 1931792391 2007347635 1909733559 1825869920 2044170013
#  2104602264 2786465559] [1.         0.82983524 0.82756734 0.8228171  0.8228043  0.8221962
#  0.8199305  0.8198794  0.8188399  0.8173102  0.81725645 0.8157397
#  0.8154375  0.8141068  0.8128588  0.81061065 0.8100102  0.8098298
#  0.8095945  0.80849373 0.8082956  0.80810225 0.80793345 0.80726826
#  0.8071704  0.8067992  0.806648   0.8056046  0.8052933  0.8052643
#  0.80484784 0.8044739  0.802582   0.80163527 0.8013518  0.79907703
#  0.79825926 0.79802686 0.7977789  0.796767   0.79630464 0.79609615
#  0.7957384  0.79560864 0.7955977  0.79520804 0.7951923  0.79352576
#  0.7934384  0.79310787]

# %%
k = 100000
s = time.time()
dists, idxs = test_index.search(normalize(merged_embeddings[q_idx]), k)
print((time.time() - s) / len(q_idx))
print(idxs[0][:50], dist2sim(dists[0][:50]))
# Out:
# 0.00024988651275634763
# [81221 91605 13887 13422 58312  5242 92633  8334 18152 24050 39959 17565
#  79906 99871 56659  3701 96907 50798 43613 97405  6513 84949 65146 44767
#  51473 87039 57179 56075 73405 10997 31671 33542 52356 60175 70093 50863
#  98783 26499 59594  5763  5988 28529 42379 61695 33629 18981 28784 40593
#   9460 28848] [1.         0.82983524 0.82756734 0.8228171  0.8228043  0.8221962
#  0.8199305  0.8198794  0.8188399  0.8173102  0.81725645 0.8157397
#  0.8154375  0.8141068  0.8128588  0.81061065 0.8100102  0.8098298
#  0.8095945  0.80849373 0.8082956  0.80810225 0.80793345 0.80726826
#  0.8071704  0.8067992  0.806648   0.8056046  0.8052933  0.8052643
#  0.80484784 0.8044739  0.802582   0.80163527 0.8013518  0.79907703
#  0.79825926 0.79802686 0.7977789  0.796767   0.79630464 0.79609615
#  0.7957384  0.79560864 0.7955977  0.79520804 0.7951923  0.79352576
#  0.7934384  0.79310787]

# %%
test_index.ntotal
# Out:
# 5

# %%
faiss.write_index(test_index2, "index_mapped.index")

# %%
test_mapped = faiss.read_index("index_mapped.index")

# %%
k = 100000
s = time.time()
dists, idxs = test_mapped.search(normalize(merged_embeddings[q_idx]), k)
print((time.time() - s) / len(q_idx))
print(idxs[0][:50], dist2sim(dists[0][:50]))
# Out:
# 0.0003398799896240234
# [2127650263 2085583171 2160684493 1595483645 2142544755 2194321275
#  2340427832 2170805580 2770298516 2130105540 2751118800 2164479831
#  1993309788 1892722218 2467980042 2123967136 2121557314 2214145768
#   208252816 2029269644 2269778407 2130318956 2074668887 1504448809
#  2593658277 2015103117 2006273250 2767050701 2564726951 2588610957
#  1983801113   53987483 2006859604 1987326241 2118459920 1989549063
#  1987409251 1965417459 2040990302  105964407 2146571341 2113592754
#  2201912979 1931792391 2007347635 1909733559 1825869920 2044170013
#  2104602264 2786465559] [1.         0.82983524 0.82756734 0.8228171  0.8228043  0.8221962
#  0.8199305  0.8198794  0.8188399  0.8173102  0.81725645 0.8157397
#  0.8154375  0.8141068  0.8128588  0.81061065 0.8100102  0.8098298
#  0.8095945  0.80849373 0.8082956  0.80810225 0.80793345 0.80726826
#  0.8071704  0.8067992  0.806648   0.8056046  0.8052933  0.8052643
#  0.80484784 0.8044739  0.802582   0.80163527 0.8013518  0.79907703
#  0.79825926 0.79802686 0.7977789  0.796767   0.79630464 0.79609615
#  0.7957384  0.79560864 0.7955977  0.79520804 0.7951923  0.79352576
#  0.7934384  0.79310787]

# %%
# Write stuff with mapped ids

# %%
dim = 768
index_type = 'hnsw'

merged_embeddings_index = get_index(index_type, dim)
separate_embeddings_index = get_index(index_type, dim)
retro_separate_embeddings_index = get_index(index_type, dim)
retro_merged_embeddings_index = get_index(index_type, dim)

# %%
merged_embeddings_index_mapped = populate_and_index_map(merged_embeddings_index, merged_embeddings)
faiss.write_index(merged_embeddings_index_mapped, "Mapped_indeces/merged_embeddings_faiss.index")

separate_embeddings_index_mapped = populate_and_index_map(separate_embeddings_index, separate_embeddings)
faiss.write_index(separate_embeddings_index_mapped, "Mapped_indeces/separate_embeddings_faiss.index")

retro_separate_embeddings_index_mapped = populate_and_index_map(retro_separate_embeddings_index, separate_retro_embeddings)
faiss.write_index(retro_separate_embeddings_index_mapped, "Mapped_indeces/retro_separate_embeddings_faiss.index")

retro_merged_embeddings_index_mapped = populate_and_index_map(retro_merged_embeddings_index, merged_retro_embeddings)
faiss.write_index(retro_merged_embeddings_index_mapped, "Mapped_indeces/retro_merged_embeddings_faiss.index")

# %%
random.seed(2020)
q_idx = [random.randint(0, merged_embeddings.shape[0]) for _ in range(100)]

k = 100
s = time.time()
dists, idxs = retro_merged_embeddings_index_mapped.search(normalize(merged_embeddings[q_idx]), k)
print((time.time() - s) / len(q_idx))
print(idxs[0][:50], dist2sim(dists[0][:50]))
# Out:
# 0.00012667179107666015
# [2127650263 2588610957 2085583171 2003664523 2552241273 2078639473
#  2164479831 2416041116 2007347635 2593658277 2083281082 2770379238
#  1836465849 2194321275 1983801113 2221677593 2770298516 1513988862
#  2185898173 2739330054 1595483645 2123565204 2806970737 2006273250
#  2767050701 2252143850 2724651715 2620761940 2130750514 2122480991
#  2053978470 2123967136 2085606725 2201467212 2269778407 2062465628
#  2148112459 2757631751  121023703 2524545028 2467980042 2135719924
#  2201912979 1729873854 1488195763 2132295085 2291575139 2111119385
#  1574909006 1557517019] [0.956792   0.85677725 0.8562635  0.8536861  0.8522803  0.8499435
#  0.8491037  0.8487227  0.8480271  0.8466462  0.8465451  0.8452147
#  0.84481    0.8442543  0.8438333  0.84381014 0.84300447 0.8428029
#  0.8425627  0.8424239  0.8423993  0.8416184  0.8412725  0.839786
#  0.8392     0.8384499  0.8379636  0.8369426  0.83535814 0.8352574
#  0.83433306 0.8336283  0.83348763 0.83330584 0.8332734  0.83310306
#  0.8322484  0.8318646  0.8318517  0.8316897  0.8314148  0.83102506
#  0.83079946 0.8307195  0.8299242  0.82990074 0.82954955 0.82915646
#  0.82907796 0.8290359 ]
